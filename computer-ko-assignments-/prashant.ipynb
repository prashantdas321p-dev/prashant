# %% [markdown]
# 1. Draw a sine wave using matplotlib for 𝑥 from 0 to 2𝜋. in python

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create x values from 0 to 2π
x = np.linspace(0, 2 * np.pi, 100)

# Calculate sine of x
y = np.sin(x)

# Plot the sine wave
plt.plot(x, y)

# Add labels and title
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.title("Sine Wave")

# Show the graph
plt.show()

# %% [markdown]
# 2. Write a function-based Python program to compute the factorial of a number.

# %%
def factorial(n):
    if n < 0:
        return "Factorial is not defined for negative numbers"
    elif n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)

# Take input from the user
num = int(input("Enter a number: "))

# Call the function and print the result
result = factorial(num)
print("Factorial of", num, "is:", result)

# %% [markdown]
# Enter a number: 5
# Factorial of 5 is: 120

# %% [markdown]
# 3. Write a Python script that prints all prime numbers between 1 and 100.

# %%
for num in range(2, 101):
    is_prime = True
    for i in range(2, int(num ** 0.5) + 1):
        if num % i == 0:
            is_prime = False
            break
    if is_prime:
        print(num)

# %% [markdown]
# 2
# 3
# 5
# 7
# 11
# 13
# 17
# 19
# ...
# 97
